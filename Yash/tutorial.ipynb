# %%
# %run spiral_neuralnet.py --plot --interactive
# Out:
# GPU is not enabled in this notebook
# Random seed 2022 has been set.
# C:\Yash Dev\Summer2024\Yash\spiral_neuralnet.py:563: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#   0%|          | 0/2 [00:00<?, ?it/s]
# C:\Yash Dev\Summer2024\Yash\spiral_neuralnet.py:449: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Yash Dev\Summer2024\Yash\spiral_neuralnet.py:503: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# C:\Yash Dev\Summer2024\Yash\spiral_neuralnet.py:616: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
net
# Out:
# Net(
#   (mlp): Sequential(
#     (0): Linear(in_features=2, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=32, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=32, out_features=4, bias=True)
#     (5): ReLU()
#   )
# )
